# %%
import time

# %%
indonesian_negative_words = [
    'ngata', 'cemooh','olok',
    'jelek', 'menertawakan', 'cibiran',
    'nyinyir',
]

religious_words = [
    'Agama', 'Islam', 'Kristen',
    'Buddha', 'Hindu', 'Konghucu',
    'Katolik', 'Protestan',
]

# %%
delay = 60  # delay in seconds
i = 1

# Loop over the list of strings and run the command for each string
for words in indonesian_negative_words:
    for religion in religious_words:
        query = words + ' ' + religion
        if i == 1:
            print(f"Scraping: {i}. {query}\n")
        else:
            print(f"\n\nScraping: {i}. {query}\n")

        i += 1

        # Construct the shell command with the above query
        # Resource 1 (most useful): https://stackoverflow.com/questions/57330956/ipython-notebook-using-quotes-and-dollar-to-pass-string-variable-as-argum#:~:text=Any%20input%20line,in%20your%20line.
        # Resource 2: (didn't work for me): https://stackoverflow.com/questions/61606054/passing-ipython-variables-as-string-arguments-to-shell-command
        # !python scraper -t 1500 -q "$query" --latest

        # Wait for the specified delay
        time.sleep(delay)
# Out:
# Scraping: 45. cibiran Hindu
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from cibiran Hindu search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.27% 4 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 9 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_22-48-47_cibiran_Hindu_tweets_1-9.csv
# CSV Saved: ./tweets/2024-05-30_22-48-47_cibiran_Hindu_tweets_1-9.csv
#
#
# Scraping: 46. cibiran Konghucu
#
#
#
# Scraping: 47. cibiran Katolik
#
#
#
# Scraping: 48. cibiran Protestan
#
#
#
# Scraping: 49. nyinyir Agama
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Agama search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# Progress: [[----------------------------------------]] 0.60% 9 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 9 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_22-56-23_nyinyir_Agama_tweets_1-9.csv
# CSV Saved: ./tweets/2024-05-30_22-56-23_nyinyir_Agama_tweets_1-9.csv
#
#
# Scraping: 50. nyinyir Islam
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Islam search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 1.27% 19 of 1500
# Progress: [[=---------------------------------------]] 3.53% 53 of 1500
# Progress: [[=======---------------------------------]] 18.13% 272 of 1500
# Progress: [[=======---------------------------------]] 19.27% 289 of 1500
# Progress: [[=========-------------------------------]] 22.53% 338 of 1500
# Progress: [[=========-------------------------------]] 23.47% 352 of 1500
# Progress: [[==========------------------------------]] 26.60% 399 of 1500
# Progress: [[===============-------------------------]] 38.73% 581 of 1500
# Progress: [[=================-----------------------]] 43.00% 645 of 1500 - waiting to access older tweets 0 min on 15 min
# Progress: [[=================-----------------------]] 43.00% 645 of 1500 - waiting to access older tweets 1 min on 15 min
# Progress: [[=================-----------------------]] 43.00% 645 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# Progress: [[=================-----------------------]] 43.33% 650 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 650 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-04-18_nyinyir_Islam_tweets_1-650.csv
# CSV Saved: ./tweets/2024-05-30_23-04-18_nyinyir_Islam_tweets_1-650.csv
#
#
# Scraping: 51. nyinyir Kristen
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Kristen search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[==============--------------------------]] 36.80% 552 of 1500
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 0 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 1 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 2 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 3 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 4 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 5 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 6 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 7 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 8 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 9 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 10 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 11 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 12 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 13 min on 15 min
# Progress: [[==================----------------------]] 46.60% 699 of 1500 - waiting to access older tweets 14 min on 15 min
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 699 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-28-06_nyinyir_Kristen_tweets_1-699.csv
# CSV Saved: ./tweets/2024-05-30_23-28-06_nyinyir_Kristen_tweets_1-699.csv
#
#
# Scraping: 52. nyinyir Buddha
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Buddha search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# Progress: [[=---------------------------------------]] 4.80% 72 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 72 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-30-32_nyinyir_Buddha_tweets_1-72.csv
# CSV Saved: ./tweets/2024-05-30_23-30-32_nyinyir_Buddha_tweets_1-72.csv
#
#
# Scraping: 53. nyinyir Hindu
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Hindu search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 2.33% 35 of 1500
# Progress: [[=---------------------------------------]] 4.40% 66 of 1500
# Progress: [[=---------------------------------------]] 4.40% 66 of 1500
# Progress: [[==--------------------------------------]] 5.27% 79 of 1500
# Progress: [[==--------------------------------------]] 6.93% 104 of 1500
# Progress: [[===-------------------------------------]] 9.93% 149 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# Progress: [[======----------------------------------]] 15.27% 229 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 229 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-33-15_nyinyir_Hindu_tweets_1-229.csv
# CSV Saved: ./tweets/2024-05-30_23-33-15_nyinyir_Hindu_tweets_1-229.csv
#
#
# Scraping: 54. nyinyir Konghucu
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Konghucu search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# Progress: [[----------------------------------------]] 2.20% 33 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 33 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-35-05_nyinyir_Konghucu_tweets_1-33.csv
# CSV Saved: ./tweets/2024-05-30_23-35-05_nyinyir_Konghucu_tweets_1-33.csv
#
#
# Scraping: 55. nyinyir Katolik
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Katolik search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[=---------------------------------------]] 4.53% 68 of 1500
# Progress: [[==--------------------------------------]] 5.67% 85 of 1500
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 0 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 1 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 2 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 3 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 4 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 5 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 6 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 7 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 8 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 9 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 10 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 11 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 12 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 13 min on 15 min
# Progress: [[====------------------------------------]] 10.20% 153 of 1500 - waiting to access older tweets 14 min on 15 min
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 153 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-52-33_nyinyir_Katolik_tweets_1-153.csv
# CSV Saved: ./tweets/2024-05-30_23-52-33_nyinyir_Katolik_tweets_1-153.csv
#
#
# Scraping: 56. nyinyir Protestan
#
# Loading .env file
# Loaded .env file
#
#
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing FirefoxDriver...
# WebDriver Setup Complete
#
# Logging in to Twitter...
#
# Login Successful
#
# Scraping Latest Tweets from nyinyir Protestan search...
#
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 0.00% 0 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# Progress: [[----------------------------------------]] 1.60% 24 of 1500
# No more tweets to scrape
#
# Scraping Incomplete
# Tweets: 24 out of 1500
#
# Saving Tweets to CSV...
# ./tweets/2024-05-30_23-54-25_nyinyir_Protestan_tweets_1-24.csv
# CSV Saved: ./tweets/2024-05-30_23-54-25_nyinyir_Protestan_tweets_1-24.csv
